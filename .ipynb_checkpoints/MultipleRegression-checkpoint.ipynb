# %%
import pandas as pd
import numpy as np

# %%
nasdaqFile = "/users/nirmalanawale/nirmi/myworkspace/python/data/nasdaq.csv"
spFile = "/users/nirmalanawale/nirmi/myworkspace/python/data/sp_500.csv"
googFile = "/users/nirmalanawale/nirmi/myworkspace/python/data/goog.csv"
oilFile = "/users/nirmalanawale/nirmi/myworkspace/python/data/uso.csv"
xomFile = "/users/nirmalanawale/nirmi/myworkspace/python/data/xom.csv"

# %%
def readFile(filename):
    data = pd.read_csv(filename, sep = ",", usecols =[0,6], names = ["Date", "Price"], header = 0)
    returns = np.array(data["Price"][:-1] , np.float)/np.array(data["Price"][1:], np.float) - 1
    data["Returns"] = np.append(returns, np.nan)
    data.index = data["Date"]
    return data

# %%
from sklearn import datasets, linear_model

# %%
oilData = readFile(oilFile)

# %%
# to remove last 'NaN' value
oilDataUnfilled = oilData["Returns"][0:-1]

# %%
nasdaqData = readFile(nasdaqFile)

# %%
nasdaqDataFilled = nasdaqData["Returns"][0:-1]

# %%
nasdaqDataFilled = nasdaqDataFilled[0:len(oilDataUnfilled)]

# %%
nasdaqDataFilled
# Out:
# Date
# 2018-07-27    0.015284
# 2018-07-30   -0.023526
# 2018-07-31   -0.012817
# 2018-08-01    0.068347
# 2018-08-02    0.031010
# 2018-08-03   -0.098058
# 2018-08-06    0.018466
# 2018-08-07    0.052561
# 2018-08-08    0.027005
# 2018-08-09   -0.029702
# 2018-08-10    0.094523
# 2018-08-13   -0.001627
# 2018-08-14   -0.161612
# 2018-08-15    0.155299
# 2018-08-16    0.073998
# 2018-08-17    0.084863
# 2018-08-20   -0.038299
# 2018-08-21    0.063940
# 2018-08-22   -0.116725
# 2018-08-23   -0.003557
# 2018-08-24   -0.186505
# 2018-08-27    0.182445
# 2018-08-28    0.033896
# 2018-08-29   -0.058304
# 2018-08-30    0.060287
# 2018-08-31   -0.147839
# 2018-09-04   -0.141429
# 2018-09-05    0.096298
# 2018-09-06    0.103570
# 2018-09-07    0.051400
#                 ...
# 2018-09-14   -0.109634
# 2018-09-17   -0.014603
# 2018-09-18    0.074771
# 2018-09-19   -0.057023
# 2018-09-20   -0.382989
# 2018-09-21    0.534039
# 2018-09-24    0.056046
# 2018-09-25   -0.003870
# 2018-09-26    0.118446
# 2018-09-27   -0.116255
# 2018-09-28    0.017830
# 2018-10-01   -0.045221
# 2018-10-02   -0.215257
# 2018-10-03   -0.069390
# 2018-10-04    0.225093
# 2018-10-05    0.193451
# 2018-10-08   -0.089222
# 2018-10-09   -0.200918
# 2018-10-10   -0.019737
# 2018-10-11    0.184508
# 2018-10-12    0.233353
# 2018-10-15   -0.180860
# 2018-10-16    0.109349
# 2018-10-17   -0.071184
# 2018-10-18    0.005422
# 2018-10-19    0.109455
# 2018-10-22   -0.165735
# 2018-10-23   -0.068038
# 2018-10-24    0.070661
# 2018-10-25   -0.075206
# Name: Returns, Length: 64, dtype: float64

# %%
# verticall stack array
combined = np.stack((nasdaqDataFilled, oilDataUnfilled))

# %%
combined
# Out:
# array([[ 0.01528406, -0.02352566, -0.01281734,  0.06834671,  0.03101006,
#         -0.09805779,  0.01846568,  0.05256125,  0.02700509, -0.02970151,
#          0.09452315, -0.00162724, -0.16161192,  0.15529871,  0.07399832,
#          0.08486318, -0.03829891,  0.06394011, -0.11672491, -0.00355666,
#         -0.18650528,  0.18244532,  0.03389562, -0.05830376,  0.06028707,
#         -0.147839  , -0.141429  ,  0.09629836,  0.10356973,  0.05139974,
#         -0.12013671, -0.0092491 ,  0.00997533,  0.14013729, -0.10963426,
#         -0.01460317,  0.0747706 , -0.05702293, -0.38298865,  0.53403852,
#          0.05604552, -0.00387022,  0.11844559, -0.11625515,  0.01783   ,
#         -0.04522094, -0.21525729, -0.06938969,  0.2250926 ,  0.19345073,
#         -0.08922181, -0.20091768, -0.01973695,  0.18450811,  0.23335272,
#         -0.18085999,  0.1093491 , -0.07118364,  0.00542212,  0.10945496,
#         -0.16573459, -0.06803836,  0.07066135, -0.07520625],
#        [-0.1262739 ,  0.06133995, -0.10323069,  0.04358397,  0.05180459,
#         -0.19296564,  0.52840315, -0.53674194,  0.78888751, -0.10519898,
#         -0.34105427,  0.44544749, -0.60178732,  1.57557529, -0.09549486,
#          0.1653027 ,  0.63400351, -0.47178548,  0.76059526, -0.19381541,
#          0.31614156,  0.01281442, -0.3944468 ,  0.23619531,  0.30275021,
#         -0.2682265 ,  0.16795613, -0.17153503,  0.13022322,  0.38298814,
#         -0.19900574, -0.33446658,  0.01203688,  0.12646412,  0.13413713,
#         -0.01799477, -0.15894957,  0.18246821, -0.47924358,  0.14860191,
#          0.34893657,  0.6541861 , -0.0608306 , -0.36372866, -0.29400573,
#          0.63947993, -0.38995279, -0.00672305,  0.01442387,  0.31534313,
#         -0.15080728,  0.28889971, -0.39312486,  0.11453875,  0.1943516 ,
#          0.2116126 , -0.41565952,  0.32213968,  0.1607077 ,  0.17951185,
#         -0.62635688,  0.72998815,  0.75632274, -0.29183453]])

# %%
# but we want the arrays to be horizontally stacked
# use transpose operation
combined = combined.T

# %%
combined
[x11, ]
# Out:
# array([[ 0.01528406, -0.1262739 ],
#        [-0.02352566,  0.06133995],
#        [-0.01281734, -0.10323069],
#        [ 0.06834671,  0.04358397],
#        [ 0.03101006,  0.05180459],
#        [-0.09805779, -0.19296564],
#        [ 0.01846568,  0.52840315],
#        [ 0.05256125, -0.53674194],
#        [ 0.02700509,  0.78888751],
#        [-0.02970151, -0.10519898],
#        [ 0.09452315, -0.34105427],
#        [-0.00162724,  0.44544749],
#        [-0.16161192, -0.60178732],
#        [ 0.15529871,  1.57557529],
#        [ 0.07399832, -0.09549486],
#        [ 0.08486318,  0.1653027 ],
#        [-0.03829891,  0.63400351],
#        [ 0.06394011, -0.47178548],
#        [-0.11672491,  0.76059526],
#        [-0.00355666, -0.19381541],
#        [-0.18650528,  0.31614156],
#        [ 0.18244532,  0.01281442],
#        [ 0.03389562, -0.3944468 ],
#        [-0.05830376,  0.23619531],
#        [ 0.06028707,  0.30275021],
#        [-0.147839  , -0.2682265 ],
#        [-0.141429  ,  0.16795613],
#        [ 0.09629836, -0.17153503],
#        [ 0.10356973,  0.13022322],
#        [ 0.05139974,  0.38298814],
#        [-0.12013671, -0.19900574],
#        [-0.0092491 , -0.33446658],
#        [ 0.00997533,  0.01203688],
#        [ 0.14013729,  0.12646412],
#        [-0.10963426,  0.13413713],
#        [-0.01460317, -0.01799477],
#        [ 0.0747706 , -0.15894957],
#        [-0.05702293,  0.18246821],
#        [-0.38298865, -0.47924358],
#        [ 0.53403852,  0.14860191],
#        [ 0.05604552,  0.34893657],
#        [-0.00387022,  0.6541861 ],
#        [ 0.11844559, -0.0608306 ],
#        [-0.11625515, -0.36372866],
#        [ 0.01783   , -0.29400573],
#        [-0.04522094,  0.63947993],
#        [-0.21525729, -0.38995279],
#        [-0.06938969, -0.00672305],
#        [ 0.2250926 ,  0.01442387],
#        [ 0.19345073,  0.31534313],
#        [-0.08922181, -0.15080728],
#        [-0.20091768,  0.28889971],
#        [-0.01973695, -0.39312486],
#        [ 0.18450811,  0.11453875],
#        [ 0.23335272,  0.1943516 ],
#        [-0.18085999,  0.2116126 ],
#        [ 0.1093491 , -0.41565952],
#        [-0.07118364,  0.32213968],
#        [ 0.00542212,  0.1607077 ],
#        [ 0.10945496,  0.17951185],
#        [-0.16573459, -0.62635688],
#        [-0.06803836,  0.72998815],
#        [ 0.07066135,  0.75632274],
#        [-0.07520625, -0.29183453]])

# %%
# y data
xomData = readFile(xomFile)
xomDataFilled = xomData["Returns"][0:-1][0:len(oilDataUnfilled)]

# %%
xomNasdaqOilModel = linear_model.LinearRegression()

# %%
xomNasdaqOilModel.fit(combined,xomDataFilled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
xomNasdaqOilModel.score(combined,xomDataFilled)
# Out:
# 0.31874619144429406

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(combined)

# %%
model = sm.OLS(xomDataFilled, x)

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Returns   R-squared:                       0.319
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     14.27
# Date:                Sun, 28 Oct 2018   Prob (F-statistic):           8.24e-06
# Time:                        22:54:44   Log-Likelihood:                 1.1548
# No. Observations:                  64   AIC:                             3.690
# Df Residuals:                      61   BIC:                             10.17
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0292      0.031      0.947      0.348      -0.032       0.091
# x1             1.1076      0.231      4.795      0.000       0.646       1.570
# x2             0.1076      0.077      1.393      0.169      -0.047       0.262
# ==============================================================================
# Omnibus:                        0.042   Durbin-Watson:                   2.454
# Prob(Omnibus):                  0.979   Jarque-Bera (JB):                0.069
# Skew:                           0.045   Prob(JB):                        0.966
# Kurtosis:                       2.867   Cond. No.                         7.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# multiple linear model for categorical data
googData = readFile(googFile)

# %%
googData
# Out:
#                   Date    Price   Returns
# Date
# 2018-07-27  2018-07-27  2130600  0.151738
# 2018-07-30  2018-07-30  1849900  0.124764
# 2018-07-31  2018-07-31  1644700  0.049451
# 2018-08-01  2018-08-01  1567200  0.023444
# 2018-08-02  2018-08-02  1531300  0.405378
# 2018-08-03  2018-08-03  1089600  0.007303
# 2018-08-06  2018-08-06  1081700 -0.275971
# 2018-08-07  2018-08-07  1494000  0.090272
# 2018-08-08  2018-08-08  1370300  0.627821
# 2018-08-09  2018-08-09   841800 -0.240732
# 2018-08-10  2018-08-10  1108700  0.157186
# 2018-08-13  2018-08-13   958100 -0.289296
# 2018-08-14  2018-08-14  1348100 -0.262850
# 2018-08-15  2018-08-15  1828800  0.361525
# 2018-08-16  2018-08-16  1343200 -0.033391
# 2018-08-17  2018-08-17  1389600  0.595774
# 2018-08-20  2018-08-20   870800 -0.277704
# 2018-08-21  2018-08-21  1205600  0.358576
# 2018-08-22  2018-08-22   887400 -0.105984
# 2018-08-23  2018-08-23   992600  0.048595
# 2018-08-24  2018-08-24   946600 -0.181354
# 2018-08-27  2018-08-27  1156300 -0.113267
# 2018-08-28  2018-08-28  1304000  0.003926
# 2018-08-29  2018-08-29  1298900 -0.024410
# 2018-08-30  2018-08-30  1331400 -0.267012
# 2018-08-31  2018-08-31  1816400 -0.007974
# 2018-09-04  2018-09-04  1831000 -0.111726
# 2018-09-05  2018-09-05  2061300  0.091501
# 2018-09-06  2018-09-06  1888500  0.347677
# 2018-09-07  2018-09-07  1401300  0.256321
# ...                ...      ...       ...
# 2018-09-17  2018-09-17  1306500  0.085494
# 2018-09-18  2018-09-18  1203600  0.010240
# 2018-09-19  2018-09-19  1191400 -0.015372
# 2018-09-20  2018-09-20  1210000 -0.725350
# 2018-09-21  2018-09-21  4405600  2.466247
# 2018-09-24  2018-09-24  1271000  0.299990
# 2018-09-25  2018-09-25   977700 -0.331396
# 2018-09-26  2018-09-26  1462300  0.159819
# 2018-09-27  2018-09-27  1260800 -0.086774
# 2018-09-28  2018-09-28  1380600  0.016942
# 2018-10-01  2018-10-01  1357600 -0.195687
# 2018-10-02  2018-10-02  1687900  0.343655
# 2018-10-03  2018-10-03  1256200 -0.431455
# 2018-10-04  2018-10-04  2209500  0.865659
# 2018-10-05  2018-10-05  1184300 -0.387135
# 2018-10-08  2018-10-08  1932400  0.476580
# 2018-10-09  2018-10-09  1308700 -0.510894
# 2018-10-10  2018-10-10  2675700 -0.092675
# 2018-10-11  2018-10-11  2949000  0.403417
# 2018-10-12  2018-10-12  2101300  0.531113
# 2018-10-15  2018-10-15  1372400 -0.288359
# 2018-10-16  2018-10-16  1928500  0.314408
# 2018-10-17  2018-10-17  1467200 -0.299499
# 2018-10-18  2018-10-18  2094500  0.652335
# 2018-10-19  2018-10-19  1267600 -0.162858
# 2018-10-22  2018-10-22  1514200 -0.180938
# 2018-10-23  2018-10-23  1848700 -0.067444
# 2018-10-24  2018-10-24  1982400 -0.221306
# 2018-10-25  2018-10-25  2545800 -0.391859
# 2018-10-26  2018-10-26  4186200       NaN
#
# [65 rows x 3 columns]

# %%
googData["Months"] = [int(x[5:7]) for x in googData["Date"]]

# %%
googData
# Out:
#                   Date    Price   Returns  Months
# Date
# 2018-07-27  2018-07-27  2130600  0.151738       7
# 2018-07-30  2018-07-30  1849900  0.124764       7
# 2018-07-31  2018-07-31  1644700  0.049451       7
# 2018-08-01  2018-08-01  1567200  0.023444       8
# 2018-08-02  2018-08-02  1531300  0.405378       8
# 2018-08-03  2018-08-03  1089600  0.007303       8
# 2018-08-06  2018-08-06  1081700 -0.275971       8
# 2018-08-07  2018-08-07  1494000  0.090272       8
# 2018-08-08  2018-08-08  1370300  0.627821       8
# 2018-08-09  2018-08-09   841800 -0.240732       8
# 2018-08-10  2018-08-10  1108700  0.157186       8
# 2018-08-13  2018-08-13   958100 -0.289296       8
# 2018-08-14  2018-08-14  1348100 -0.262850       8
# 2018-08-15  2018-08-15  1828800  0.361525       8
# 2018-08-16  2018-08-16  1343200 -0.033391       8
# 2018-08-17  2018-08-17  1389600  0.595774       8
# 2018-08-20  2018-08-20   870800 -0.277704       8
# 2018-08-21  2018-08-21  1205600  0.358576       8
# 2018-08-22  2018-08-22   887400 -0.105984       8
# 2018-08-23  2018-08-23   992600  0.048595       8
# 2018-08-24  2018-08-24   946600 -0.181354       8
# 2018-08-27  2018-08-27  1156300 -0.113267       8
# 2018-08-28  2018-08-28  1304000  0.003926       8
# 2018-08-29  2018-08-29  1298900 -0.024410       8
# 2018-08-30  2018-08-30  1331400 -0.267012       8
# 2018-08-31  2018-08-31  1816400 -0.007974       8
# 2018-09-04  2018-09-04  1831000 -0.111726       9
# 2018-09-05  2018-09-05  2061300  0.091501       9
# 2018-09-06  2018-09-06  1888500  0.347677       9
# 2018-09-07  2018-09-07  1401300  0.256321       9
# ...                ...      ...       ...     ...
# 2018-09-17  2018-09-17  1306500  0.085494       9
# 2018-09-18  2018-09-18  1203600  0.010240       9
# 2018-09-19  2018-09-19  1191400 -0.015372       9
# 2018-09-20  2018-09-20  1210000 -0.725350       9
# 2018-09-21  2018-09-21  4405600  2.466247       9
# 2018-09-24  2018-09-24  1271000  0.299990       9
# 2018-09-25  2018-09-25   977700 -0.331396       9
# 2018-09-26  2018-09-26  1462300  0.159819       9
# 2018-09-27  2018-09-27  1260800 -0.086774       9
# 2018-09-28  2018-09-28  1380600  0.016942       9
# 2018-10-01  2018-10-01  1357600 -0.195687      10
# 2018-10-02  2018-10-02  1687900  0.343655      10
# 2018-10-03  2018-10-03  1256200 -0.431455      10
# 2018-10-04  2018-10-04  2209500  0.865659      10
# 2018-10-05  2018-10-05  1184300 -0.387135      10
# 2018-10-08  2018-10-08  1932400  0.476580      10
# 2018-10-09  2018-10-09  1308700 -0.510894      10
# 2018-10-10  2018-10-10  2675700 -0.092675      10
# 2018-10-11  2018-10-11  2949000  0.403417      10
# 2018-10-12  2018-10-12  2101300  0.531113      10
# 2018-10-15  2018-10-15  1372400 -0.288359      10
# 2018-10-16  2018-10-16  1928500  0.314408      10
# 2018-10-17  2018-10-17  1467200 -0.299499      10
# 2018-10-18  2018-10-18  2094500  0.652335      10
# 2018-10-19  2018-10-19  1267600 -0.162858      10
# 2018-10-22  2018-10-22  1514200 -0.180938      10
# 2018-10-23  2018-10-23  1848700 -0.067444      10
# 2018-10-24  2018-10-24  1982400 -0.221306      10
# 2018-10-25  2018-10-25  2545800 -0.391859      10
# 2018-10-26  2018-10-26  4186200       NaN      10
#
# [65 rows x 4 columns]

# %%
#dummy = sm.categorical(googData["Months"].values.reshape(1,-1). drop = True)
# Out:
#   File "<ipython-input-38-6337adeba41c>", line 1
#     dummy = sm.categorical(googData["Months"].values.reshape(1,-1). drop = True)
#                           ^
# SyntaxError: keyword can't be an expression
